# %%
from sklearn import tree # for decision tree
from sklearn.model_selection import train_test_split # for splitting dataset as training & test data

# %% [markdown]
# # Program 1
# ## Program to predict Male or Female using the length of Hair and their Height

# %%
X = [[165,19],[175,32],[136,35],[174,65],[141,28],[176,15],[131,32],[166,6],[128,32],[179,18],[136,34],[186,2]]

Y = ['Man','Woman','Woman','Man','Woman','Man','Woman','Man','Woman','Man','Woman','Woman']

data_feature_names=['height', 'length of hair']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
DTclf = tree.DecisionTreeClassifier()
DTclf = DTclf.fit(X, Y)

# %%
print(DTclf.predict([[135, 29]]))
# Out:
# ['Woman']

# %%
# Out:
# []
