# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('penguins_classification.csv')

# %%
print(df.to_string())
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)    Species
# 0                  39.1               18.7     Adelie
# 1                  39.5               17.4     Adelie
# 2                  40.3               18.0     Adelie
# 3                  36.7               19.3     Adelie
# 4                  39.3               20.6     Adelie
# 5                  38.9               17.8     Adelie
# 6                  39.2               19.6     Adelie
# 7                  34.1               18.1     Adelie
# 8                  42.0               20.2     Adelie
# 9                  37.8               17.1     Adelie
# 10                 37.8               17.3     Adelie
# 11                 41.1               17.6     Adelie
# 12                 38.6               21.2     Adelie
# 13                 34.6               21.1     Adelie
# 14                 36.6               17.8     Adelie
# 15                 38.7               19.0     Adelie
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Culmen Length (mm)  342 non-null    float64
#  1   Culmen Depth (mm)   342 non-null    float64
#  2   Species             342 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 8.1+ KB

# %%
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
cul_leng = df['Culmen Length (mm)']
cul_depth = df['Culmen Depth (mm)']

# %%
print(cul_leng)
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3      36.7
# 4      39.3
#        ...
# 337    55.8
# 338    43.5
# 339    49.6
# 340    50.8
# 341    50.2
# Name: Culmen Length (mm), Length: 342, dtype: float64

# %%
plt.bar(cul_leng, cul_depth)
# Out:
# <BarContainer object of 342 artists>
