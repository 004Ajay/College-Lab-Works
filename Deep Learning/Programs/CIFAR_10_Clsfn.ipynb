# %% [markdown]
# Implement Feed forward neural network with three hidden layers for classification on CIFAR-10 dataset. Design and train a neural network that achieves high accuracy in classifying the images into their respective classes. Test different hyper-parameters

# %%
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and preprocess CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = to_categorical(y_train), to_categorical(y_test) # to convert int to category
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
# Define the neural network architecture
def create_model(hidden_units=None, activation=None):
    model = Sequential([
        Flatten(input_shape=(32, 32, 3)),
        Dense(hidden_units[0], activation=activation), # Hidden Layer 1
        Dense(hidden_units[1], activation=activation), # Hidden Layer 2
        Dense(hidden_units[2], activation=activation), # Hidden Layer 3
        Dense(10, activation='softmax')
    ])
    return model

# %%
# Define hyperparameters to test
hidden_units_list = [(512, 256, 128), (256, 128, 64), (1024, 512, 256)]
activation_list = ['relu', 'tanh', 'sigmoid']

# %%
results_dict = {}
counter = 1

# Loop through combinations of hidden units and activations
for hidden_units in hidden_units_list:
    for activation in activation_list:

        model = create_model(hidden_units=hidden_units, activation=activation)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
        history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test))

        _, test_acc = model.evaluate(x_test, y_test)

        model_info = { # Create a dictionary for the current iteration
            "Hidden units": hidden_units,
            "Activation": activation,
            "Test accuracy": round(test_acc * 100, 4)
        }

        results_dict[counter] = model_info  # Add the current dictionary to the results dictionary

        counter += 1
# Out:
# Epoch 1/5
# 782/782 [==============================] - 10s 5ms/step - loss: 1.8765 - accuracy: 0.3204 - val_loss: 1.6985 - val_accuracy: 0.3881
# Epoch 2/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6788 - accuracy: 0.3999 - val_loss: 1.5893 - val_accuracy: 0.4312
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5829 - accuracy: 0.4336 - val_loss: 1.5718 - val_accuracy: 0.4315
# Epoch 4/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5289 - accuracy: 0.4539 - val_loss: 1.5311 - val_accuracy: 0.4493
# Epoch 5/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.4869 - accuracy: 0.4651 - val_loss: 1.4916 - val_accuracy: 0.4640
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4916 - accuracy: 0.4640
# Epoch 1/5
# 782/782 [==============================] - 5s 5ms/step - loss: 1.9882 - accuracy: 0.2592 - val_loss: 1.8870 - val_accuracy: 0.2965
# Epoch 2/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8712 - accuracy: 0.3156 - val_loss: 1.8219 - val_accuracy: 0.3275
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8493 - accuracy: 0.3249 - val_loss: 1.8221 - val_accuracy: 0.3377
# Epoch 4/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8267 - accuracy: 0.3349 - val_loss: 1.8695 - val_accuracy: 0.2944
# Epoch 5/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8181 - accuracy: 0.3425 - val_loss: 1.7869 - val_accuracy: 0.3562
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7869 - accuracy: 0.3562
# Epoch 1/5
# 782/782 [==============================] - 5s 5ms/step - loss: 1.8916 - accuracy: 0.3071 - val_loss: 1.8175 - val_accuracy: 0.3452
# Epoch 2/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7420 - accuracy: 0.3676 - val_loss: 1.6827 - val_accuracy: 0.3832
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6802 - accuracy: 0.3971 - val_loss: 1.6540 - val_accuracy: 0.4103
# Epoch 4/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6348 - accuracy: 0.4096 - val_loss: 1.6275 - val_accuracy: 0.4125
# Epoch 5/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6065 - accuracy: 0.4209 - val_loss: 1.6093 - val_accuracy: 0.4195
# 313/313 [==============================] - 1s 3ms/step - loss: 1.6093 - accuracy: 0.4195
# Epoch 1/5
# 782/782 [==============================] - 5s 5ms/step - loss: 1.8740 - accuracy: 0.3232 - val_loss: 1.7098 - val_accuracy: 0.3865
# Epoch 2/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6839 - accuracy: 0.3965 - val_loss: 1.6363 - val_accuracy: 0.4131
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6095 - accuracy: 0.4234 - val_loss: 1.5576 - val_accuracy: 0.4430
# Epoch 4/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5535 - accuracy: 0.4439 - val_loss: 1.5603 - val_accuracy: 0.4439
# Epoch 5/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5133 - accuracy: 0.4603 - val_loss: 1.5600 - val_accuracy: 0.4440
# 313/313 [==============================] - 1s 3ms/step - loss: 1.5600 - accuracy: 0.4440
# Epoch 1/5
# 782/782 [==============================] - 5s 5ms/step - loss: 1.9735 - accuracy: 0.2748 - val_loss: 1.8527 - val_accuracy: 0.3327
# Epoch 2/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8476 - accuracy: 0.3283 - val_loss: 1.8632 - val_accuracy: 0.3356
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7995 - accuracy: 0.3506 - val_loss: 1.7896 - val_accuracy: 0.3500
# Epoch 4/5
# 782/782 [==============================] - 4s 4ms/step - loss: 1.7704 - accuracy: 0.3608 - val_loss: 1.7233 - val_accuracy: 0.3790
# Epoch 5/5
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7517 - accuracy: 0.3689 - val_loss: 1.7844 - val_accuracy: 0.3607
# 313/313 [==============================] - 1s 4ms/step - loss: 1.
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7330 - accuracy: 0.3722 - val_loss: 1.6793 - val_accuracy: 0.3956
# Epoch 3/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6764 - accuracy: 0.3932 - val_loss: 1.7271 - val_accuracy: 0.3812
# Epoch 4/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6367 - accuracy: 0.4120 - val_loss: 1.6187 - val_accuracy: 0.4200
# Epoch 5/5
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6052 - accuracy: 0.4214 - val_loss: 1.5713 - val_accuracy: 0.4371
# 313/313 [==============================] - 1s 3ms/step - loss: 1.5713 - accuracy: 0.4371

# %%
# Print the entire results dictionary
for key, value in results_dict.items():
    print(f"Run {key}:")
    for info_key, info_value in value.items():
        print(f"{info_key}: {info_value}")
    print("- -" * 15)  # Dict prints Separator

print("\n")

# Find the run with the highest test accuracy
max_accuracy_run = max(results_dict, key=lambda k: results_dict[k]["Test accuracy"])
max_accuracy_info = results_dict[max_accuracy_run]

# Print details of the run with the highest test accuracy
print("Run with the highest test accuracy:")
print(f"Run {max_accuracy_run}:")
for info_key, info_value in max_accuracy_info.items():
    print(f"{info_key}: {info_value}")
# Out:
# Run 1:
# Hidden units: (512, 256, 128)
# Activation: relu
# Test accuracy: 46.4
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 2:
# Hidden units: (512, 256, 128)
# Activation: tanh
# Test accuracy: 35.62
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 3:
# Hidden units: (512, 256, 128)
# Activation: sigmoid
# Test accuracy: 41.95
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 4:
# Hidden units: (256, 128, 64)
# Activation: relu
# Test accuracy: 44.4
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 5:
# Hidden units: (256, 128, 64)
# Activation: tanh
# Test accuracy: 36.07
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 6:
# Hidden units: (256, 128, 64)
# Activation: sigmoid
# Test accuracy: 41.93
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 7:
# Hidden units: (1024, 512, 256)
# Activation: relu
# Test accuracy: 48.47
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 8:
# Hidden units: (1024, 512, 256)
# Activation: tanh
# Test accuracy: 29.08
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# Run 9:
# Hidden units: (1024, 512, 256)
# Activation: sigmoid
# Test accuracy: 43.71
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#
# Run with the highest test accuracy:
# Run 7:
# Hidden units: (1024, 512, 256)
# Activation: relu
# Test accuracy: 48.47

# %%
num_images = 3
sample_images = x_train[:num_images]
predictions = model.predict(sample_images)

def plot_probability_meter(predictions, image):
    class_labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

    fig, axs = plt.subplots(1, 2, figsize=(10, 2))

    # Plot the image
    axs[0].imshow(image)
    axs[0].axis('off')

    # Plot the probability meter
    axs[1].barh(class_labels, predictions[0], color='blue')
    axs[1].set_xlim([0, 1])
    # axs[1].set_xlabel('Probability')

    plt.tight_layout()
    plt.show()

for i in range(num_images):
    plot_probability_meter(predictions[i:i+1], sample_images[i])
# Out:
# 1/1 [==============================] - 0s 28ms/step
